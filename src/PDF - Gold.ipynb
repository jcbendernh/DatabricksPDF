-- %% [markdown]
-- The following example uses ai_parse_document to extract document layouts as VARIANT output for files in a Unity Catalog volume.

-- %%
SELECT
  path,
  ai_parse_document(content)
FROM READ_FILES(:sourceResume, format => 'binaryFile');

-- %% [markdown]
-- The following example uses ai_parse_document to separate each top-level field of the output. For example, document.pages, document.elements, error_status, and metadata into individual columns

-- %%
WITH corpus AS (
  SELECT
    path,
    ai_parse_document(content) AS parsed
  FROM
    READ_FILES('/Volumes/catadb360dev/default/resume', format => 'binaryFile')
)

SELECT
  path,
  parsed,
  ai_query(
    'databricks-meta-llama-3-3-70b-instruct',
      concat('Extract the name, job experience, and education from the following text.',
      parsed
  ),
  returnType => 'VARIANT'
  ) AS parsed_text
  FROM corpus
